# %% [markdown]
# <a href="https://colab.research.google.com/github/Jana2333/Projekt2_Python/blob/main/Tic_Tac_Toe_doplneni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
    print("""Ahoj hraci, zde si muzete zahrat hru Tic Tac Toe.
Pravidla jsou nasledujici: kazdy hrac hada
souradnice pole. Hrac jedna ma znak X,
hrac 2 ma znak O. Kdyz hrac uhadne jako prvni
sve 3 znaky tak, aby sly za sebou vodorovne,
svisle nebo diagonalne, vyhral. Kdyz ani jeden
hrac neuhadne po sobe jdouci 3 znaky, vysledek
je remiza.
Musis zadat pouze cisla, ktera jsou v rozmezi 1-3.
Hra zacina.""")

    pocet_X=0
    pocet_O=0
    nahrad1=None
    nahrad2=tvorba_pole()
    tisk(tvorba_pole())
    while True:
        while True:
            while True:
                try:
                    h1_1=int(input("Hrac 1 zada prvni cislo."))
                    if h1_1 <1 or h1_1>3:
                        print("Zadej číslo v rozmezi 1 a 3.")
                    else:
                        break
                except ValueError:
                    print("Nezadal jsi cislo.")
                         
            while True:
                try:
                    h1_2=int(input("Hrac 1 zada druhe cislo."))
                    if h1_2 <1 or h1_2>3:
                        print("Zadej cislo v rozmezi 1 a 3.")
                    else:
                        break
                except ValueError:
                    print("Nezadal jsi cislo.")
            
            h1_1=2*h1_1-1
            h1_2=2*h1_2-1
            
            nahrad1=nahrad_X(nahrad2,h1_1,h1_2)
            if nahrad1[0]==False:
                break
       
        kontrola_X(nahrad1[1])
        if kontrola_X(nahrad1[1])==3:
            print ("Vyhral hrac 1.")  
            break   
   
        else:       
            kontrola_remiza_X(nahrad1[1])
        
        if kontrola_remiza_X(nahrad1[1])==3:
            print('Remiza.')
            break
               
  
        while True:
            while True:
                try:
                    h2_1=int(input("Hrac 2 zada prvni cislo."))
                    if h2_1 <1 or h2_1>3:
                        print("Zadej číslo v rozmezi 1 a 3.")
                    else:
                        break
                except ValueError:
                    print("Nezadal jsi cislo.")
                    
            while True:
                try:
                    h2_2=int(input("Hrac 2 zada druhe cislo."))
                    if h2_2 <1 or h2_2>3:
                        print("Zadej cislo v rozmezi 1 a 3.")
                    else:
                        break
                except ValueError:
                    print("Nezadal jsi cislo.")
            
            h2_1=2*h2_1-1
            h2_2=2*h2_2-1
            
            nahrad2=nahrad_O(nahrad1[1],h2_1,h2_2)
            if nahrad2[0]==False:
                break
        
        kontrola_O(nahrad2[1])

        if kontrola_O(nahrad2[1])==3:
            nahrad2[1]
            print("Vyhral hrac 2.")  
            break   
    
        else:       
            kontrola_remiza_O(nahrad2[1])

        if kontrola_remiza_O(nahrad2[1])==3:
          print('remiza')
          break
        
        nahrad2=nahrad2[1]

def tvorba_pole(): 
    t1=[]
    for i in range(7):
        t2=[]
        for j in range(7):
            if i%2==0:
                if j%2==0:
                    t2.append("+")
                else:
                    t2.append(3*"-")
            else:
                if j%2==0:
                    t2.append("|")
                else:
                    t2.append(" ")
        t1.append(t2)    
    return t1

def tisk(tvorba_pole):    
    for i in range(7):
        print("".join(tvorba_pole[i]))

def kontrola_X(pole):
   pocet_X=0
   pocet_X_celkem=0
   for i in range(1,len(pole)-1,2):
        for j in range(1,len(pole)-1,2):
            if pole[i][j]==" X ":
                pocet_X+=1
            else:
                pocet_X=0
            if pocet_X==3:
                pocet_X_celkem=3
            if j==5:
                pocet_X=0
           

   for i in range(1,len(pole)-1,2):
        for j in range(1,len(pole)-1,2):  
              if pole[j][i]==" X ":
                  pocet_X+=1
              else:
                  pocet_X=0
              if pocet_X==3:
                  pocet_X_celkem=3
              if j==5:
                  pocet_X=0

   for i in range(1,len(pole)-1,2):
        for j in range(1,len(pole)-1,2):
            if i==j:
                if pole[i][i]==" X ":
                    pocet_X+=1
                else:
                    pocet_X=0
                if pocet_X==3:
                    pocet_X_celkem=3
                if i==5:
                    pocet_X=0

   for i in range(1,len(pole)-1,2):
        for j in range(1,len(pole)-1,2):
            if j==len(pole)-1-i:
                if pole[i][j]== " X ":
                    pocet_X+=1
                else:
                    pocet_X=0
                if pocet_X==3:
                    pocet_X_celkem=3
                if j==1 and i==5:
                    pocet_X=0
  
   return pocet_X_celkem

def kontrola_O(pole):
   pocet_O=0
   pocet_O_celkem=0
   for i in range(1,len(pole)-1,2):
        for j in range(1,len(pole)-1,2):
                if pole[i][j]==" O ":
                     pocet_O+=1
                     
                else:
                    pocet_O=0

                if pocet_O==3:
                    pocet_O_celkem=3
                   
                if j==5:
                    pocet_O=0
           

   for i in range(1,len(pole)-1,2):
        for j in range(1,len(pole)-1,2):  
                if pole[j][i]==" O ":
                    pocet_O+=1
                else:
                    pocet_O=0
                if pocet_O==3:
                   po33cet_O_celkem=3
                if j==5:
                   pocet_O=0

   for i in range(1,len(pole)-1,2):
        for j in range(1,len(pole)-1,2):
                if i==j:
                    if pole[i][i]==" O ":
                       pocet_O+=1
                
                    else:
                       pocet_O=0
                    
                    if pocet_O==3:
                        pocet_O_celkem=3
                    if i==5:
                        pocet_O=0

           
   for i in range(1,len(pole)-1,2):
            for j in range(1,len(pole)-1,2):
               if j==len(pole)-1-i:
                  if pole[i][j]== " O ":
                       pocet_O+=1                  
                  else:
                       pocet_O=0
                  
                  if pocet_O==3:
                       pocet_O_celkem=3
                  if j==1 and i==5:
                      pocet_O=0
   return pocet_O_celkem

def kontrola_remiza_X(pole):
    pocet_remiza_X=0
    for i in range(1,len(pole)-1,2):
        if " " in pole[i]:
            break
        else:
            pocet_remiza_X+=1             
    return pocet_remiza_X

def kontrola_remiza_O(pole):
    pocet_remiza_O=0
    for i in range(1,len(pole)-1,2):
        if " " in pole[i]:
           break
        else:
           pocet_remiza_O+=1
    return pocet_remiza_O

def nahrad_X(pole, vstup1,vstup2):
    nahrad1=True
    if pole[vstup1][vstup2]==" ":
        pole[vstup1][vstup2]=" X "
        nahrad1=False
    else:
        print("Obsazeno, hraci 1, hraj jinam.")
    for i in range (7):
        print("".join(pole[i]))
    
    return nahrad1, pole

def nahrad_O(pole, vstup1, vstup2):
    nahrad2=True
    if pole[vstup1][vstup2]==" ":
        pole[vstup1][vstup2]=" O "
        nahrad2=False
    else:
        print ("Obsazeno, hraci 2, hraj jinam.")
    for i in range(7):
        print("".join(pole[i]))
    return nahrad2, pole
main()
# Out:
# Ahoj hraci, zde si muzete zahrat hru Tic Tac Toe.
# Pravidla jsou nasledujici: kazdy hrac hada
# souradnice pole. Hrac jedna ma znak X,
# hrac 2 ma znak O. Kdy hrac uhadne jako prvni
# sve 3 znaky tak, aby sly za sebou vodorovne,
# svisle nebo diagonalne, vyhral. Kdyz ani jeden
# hrac neuhadne po sobe jdouci 3 znaky, vysledek
# je remiza.
# Musis zadat pouze cisla, ktera jsou v rozmezi.
# Hra zacina.
# +---+---+---+
# | | | |
# +---+---+---+
# | | | |
# +---+---+---+
# | | | |
# +---+---+---+
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# ...
